# %%
idade = int(input("Digite sua idade: "))
carro = input("Tem carro? <S/N> ")
if idade >= 18:
    if carro == "S":
        print("Pode Dirigir!!")
    else:
        print("Chama o Uber!!")
else:
    print("Chama o Uber!!")
# Out:
# Digite sua idade:  45
# Tem carro? <S/N>  N
# Chama o Uber!!

# %%
idade = int(input("Digite sua idade: "))
carro = input("Tem carro? <S/N> ")
if (idade >= 18) and (carro == "S"):
    print("Pode Dirigir!!")   
else:
    print("Chama o Uber!!")
# Out:
# Digite sua idade:  17
# Tem carro? <S/N>  S
# Chama o Uber!!

# %%
idade = int(input("Digite sua idade: "))
carro = input("Tem carro? <S/N> ")
if idade >= 18:
    if carro == "S":
        print("Pode Dirigir!!")
    print("Chama o Uber!!")
else:
    print("Chama o Uber!!")
# Out:
# Digite sua idade:  8
# Tem carro? <S/N>  S
# Chama o Uber!!

# %%
nota1 = float(input("Digite o número"))
nota2 = float(input("Digite o número"))
media = (nota1+nota2)/2
print("A média é igual a : ", media)
if media>=5:
    print ("Aprovado(a)")
else:
    print ("Reprovado(a)")
# Out:
# Digite o número 10
# Digite o número 4
# A média é igual a :  7.0
# Aprovado(a)

# %%
nota1 = float(input("Digite o número"))
if nota1 >= 7:
    nota1 = nota1 + 0.5
nota2 = float(input("Digite o número"))
if nota2 >= 7:
    nota2 = nota2 + 0.5
media = (nota1+nota2)/2
print("A média é igual a : ", media)
if media>=5:
    print ("Aprovado(a)")
else:
    print ("Reprovado(a)")
# Out:
# Digite o número 8
# Digite o número 9
# A média é igual a :  9.0
# Aprovado(a)

# %%
print("Digite os três lados do triângulo:")
a = float(input("Encontre o lado a: "))
b = float(input("Encontre o lado b: "))
c = float(input("Encontre o lado c: "))
if (a >= b+c) or (b >= a+c) or (c >= b+c):
    print("Não é um triângulo")
else:
    if (a == b == c):
        print("Triângulo Equilátero!")
    elif (a == b) or (b == c) or (c == a):
        print("Triângulo Isóceles!")
    else:
        print("Triângulo Escaleno!")
# Out:
# Digite os três lados do triângulo:

# %%
if (a >= b+c) or (b >= a+c) or (c >= b+c):
    if (a == b == c):
        print("Triângulo Equilátero!")
    elif (a == b) or (b == c) or (c == a):
        print("Triângulo Isóceles!")
    else:
        print("Triângulo Escaleno!")
else:
    print("Não é um triângulo")
# Out:
# Não é um triângulo
